# %% [markdown]
# # 自动调度

# %%
import numpy as np
import tvm
from tvm import te, auto_scheduler

# %% [markdown]
# 工作负载（workload）实际上是由 TVM DSL 定义的计算 DAG。但是序列化计算 DAG 并有效地匹配它们并不容易。因此，需要使用字符串 `[func_name, [args...]]` 编码 compute dag（返回值为 ``func_name(*args)``）。
#
# 这些字符串对于序列化/匹配非常有效，而且不会太长。
#
# 当需要 dag 时，解码字符串并调用函数，该函数将返回 dag。

# %%
@auto_scheduler.register_workload  # 注意 auto_scheduler 装饰器
def matmul_add(N, L, M, dtype):
    A = te.placeholder((N, L), name="A", dtype=dtype)
    B = te.placeholder((L, M), name="B", dtype=dtype)
    C = te.placeholder((N, M), name="C", dtype=dtype)

    k = te.reduce_axis((0, L), name="k")
    matmul = te.compute(
        (N, M),
        lambda i, j: te.sum(A[i, k] * B[k, j], axis=k),
        name="matmul",
        attrs={"layout_free_placeholders": [B]},  # 启用张量 B 的自动布局转换
    )
    out = te.compute((N, M), lambda i, j: matmul[i, j] + C[i, j], name="out")
    return [A, B, C, out]

# %% [markdown]
# ## 搜索任务
#
# 在定义了函数之后，为 `auto_scheduler` 创建任务来进行搜索。指定这个矩阵乘法的特殊参数：`N=L=M=1024` 和 `dtype="float32"` 创建搜索任务。

# %%
# target = tvm.target.Target("llvm")
target = tvm.target.Target("llvm -mcpu=skylake-avx512")

N = L = M = 1024
task = auto_scheduler.SearchTask(func=matmul_add, args=(N, L, M, "float32"), target=target)

# 检查计算图
print("Computational DAG:")
print(task.compute_dag)
# Out:
# Computational DAG:
# A = PLACEHOLDER [1024, 1024]
# B = PLACEHOLDER [1024, 1024]
# matmul(i, j) += (A[i, k]*B[k, j])
# C = PLACEHOLDER [1024, 1024]
# out(i, j) = (matmul[i, j] + C[i, j])

# %% [markdown]
# ### 设置参数

# %%
log_file = "matmul.json"
tune_option = auto_scheduler.TuningOptions(
    num_measure_trials=10, # 搜索过程中可以使用的测量试验的数量，1000 是很好的搜索收敛值
    measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    verbose=2,
)

# %% [markdown]
# ### 运行搜索

# %%
# 运行 auto-tuning (search)
task.tune(tune_option)
# 应用最优 schedule
sch, args = task.apply_best(log_file)
# Out:
# /media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2014	fail_ct: 2	Time elapsed: 0.58
# GA Iter: 0	Max score: 0.9991	Min score: 0.9335	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9998	Min score: 0.9859	#Pop: 128	#M+: 1384	#M-: 74
# EvolutionarySearch		#s: 128	Time elapsed: 2.40
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 10 programs to measure:
# ..........*E*E*E*E***E*E*E*E
# ==================================================
# No: 1	GFLOPS: 0.00 / 0.00	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.56, Tstamp:1661835241.06)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,32)
#   for j.1 (0,256)
#     for k.0 (0,32)
#       for i.2 (0,16)
#         for k.1 (0,32)
#           for i.3 (0,2)
#             vectorize j.3 (0,4)
#               matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 2	GFLOPS: 0.00 / 0.00	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.32, Tstamp:1661835242.17)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 64
# parallel i.0@j.0@i.1@ (0,1024)
#   for k.0 (0,128)
#     for i.2 (0,32)
#       for j.2 (0,16)
#         for k.1 (0,8)
#           vectorize j.3 (0,2)
#             matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 3	GFLOPS: 0.00 / 0.00	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.40, Tstamp:1661835243.20)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,2)
#   matmul auto_unroll: 16
#   for k.0 (0,16)
#     for i.2 (0,128)
#       for j.2 (0,128)
#         for k.1 (0,64)
#           for i.3 (0,4)
#             vectorize j.3 (0,8)
#               matmul = ...
#   for i.1 (0,512)
#     for j.1 (0,1024)
#       out = ...
#
# ==================================================
# No: 4	GFLOPS: 0.00 / 0.00	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.19, Tstamp:1661835244.28)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 16
# parallel i.0@j.0@i.1@ (0,32768)
#   for j.1 (0,2)
#     for k.0 (0,256)
#       for k.1 (0,4)
#         for i.3 (0,4)
#           vectorize j.3 (0,4)
#             matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 5	GFLOPS: 186.40 / 186.40	results: MeasureResult(cost:[0.0115], error_no:0, all_cost:0.51, Tstamp:1661835245.23)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 64
# parallel i.0@j.0@ (0,512)
#   for i.1 (0,2)
#     for j.1 (0,64)
#       for k.0 (0,512)
#         for j.2 (0,2)
#           for k.1 (0,2)
#             for i.3 (0,4)
#               vectorize j.3 (0,2)
#                 matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 6	GFLOPS: 7.26 / 186.40	results: MeasureResult(cost:[0.2961], error_no:0, all_cost:2.01, Tstamp:1661835246.89)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 16
# parallel i.0@j.0@i.1@j.1@ (0,2048)
#   for k.0 (0,256)
#     for j.2 (0,2)
#       for k.1 (0,4)
#         for i.3 (0,64)
#           vectorize j.3 (0,4)
#             matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 7	GFLOPS: 0.00 / 186.40	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.72, Tstamp:1661835247.31)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@ (0,2)
#   for i.1 (0,128)
#     for j.1 (0,64)
#       for k.0 (0,128)
#         for j.2 (0,4)
#           for k.1 (0,8)
#             for i.3 (0,4)
#               vectorize j.3 (0,4)
#                 matmul = ...
#       for i.2 (0,4)
#         vectorize j.2 (0,16)
#           out = ...
#
# ==================================================
# No: 8	GFLOPS: 0.00 / 186.40	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:13.36, Tstamp:1661835248.50)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,32)
#   matmul auto_unroll: 512
#   for i.1 (0,32)
#     for j.1 (0,4)
#       for k.0 (0,16)
#         for j.2 (0,2)
#           for k.1 (0,64)
#             for i.3 (0,8)
#               vectorize j.3 (0,16)
#                 matmul = ...
#   for i.1 (0,256)
#     for j.1 (0,128)
#       out = ...
#
# ==================================================
# No: 9	GFLOPS: 0.00 / 186.40	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.57, Tstamp:1661835249.52)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,1024)
#   matmul auto_unroll: 16
#   for k.0 (0,32)
#     for i.2 (0,8)
#       for j.2 (0,16)
#         for k.1 (0,32)
#           vectorize j.3 (0,8)
#             matmul = ...
#   for i.2 (0,8)
#     for j.2 (0,128)
#       out = ...
#
# ==================================================
# No: 10	GFLOPS: 0.00 / 186.40	results: MeasureResult(error_type:RuntimeDeviceError, error_msg:Traceback (most recent call last):
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/auto_scheduler/utils.py", line 295, in call_func_with_timeout
#     res = worker.recv()
#   File "/media/pc/data/4tb/lxw/libs/anaconda3/envs/py38/lib/python3.8/site-packages/tvm/contrib/popen_pool.py", line 284, in recv
#     raise self._child_process_error()
# ChildProcessError: Subprocess terminated
# , all_cost:10.98, Tstamp:1661835250.51)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,4096)
#   matmul auto_unroll: 512
#   for i.1 (0,16)
#     for j.1 (0,2)
#       for k.0 (0,64)
#         for i.2 (0,2)
#           for j.2 (0,2)
#             for k.1 (0,16)
#               for i.3 (0,2)
#                 matmul = ...
#   for i.1 (0,64)
#     for j.1 (0,4)
#       out = ...
#
# Time elapsed for measurement: 15.93 s
# ----------------------------------------------------------------------
# ------------------------------  [ Done ]
# ----------------------------------------------------------------------

# %%
print("Lowered TIR:")
mod = tvm.lower(sch, args, simple_mode=True)
mod.show()
# Out:
# Lowered TIR:
# @tvm.script.ir_module
# class Module:
#     @T.prim_func
#     def main(A: T.Buffer[1048576, "float32"], B: T.Buffer[1048576, "float32"], C: T.Buffer[1048576, "float32"], out: T.Buffer[1048576, "float32"]) -> None:
#         # function attr dict
#         T.func_attr({"from_legacy_te_schedule": True, "global_symbol": "main", "tir.noalias": True})
#         T.preflattened_buffer(A, [1024, 1024], dtype="float32", data=A.data)
#         T.preflattened_buffer(B, [1024, 1024], dtype="float32", data=B.data)
#         T.preflattened_buffer(C, [1024, 1024], dtype="float32", data=C.data)
#         T.preflattened_buffer(out, [1024, 1024], dtype="float32", data=out.data)
#         # body
#         auto_scheduler_layout_transform = T.allocate([1048576], "float32", "global")
#         matmul = T.allocate([1048576], "float32", "global")
#         for ax0_ax1_fused_ax2_fused in T.parallel(131072):
#             for ax3, ax4, ax5 in T.grid(2, 2, 2):
#                 auto_scheduler_layout_transform[ax0_ax1_fused_ax2_fused * 8 + ax3 * 4 + ax4 * 2 + ax5] = B[ax0_ax1_fused_ax2_fused % 512 * 2048 + ax4 * 1024 + ax0_ax1_fused_ax2_fused // 512 * 4 + ax3 * 2 + ax5]
#         for i_outer_outer_outer_j_outer_outer_outer_fused in T.parallel(512):
#             for i_outer_outer_inner, j_outer_outer_inner in T.grid(2, 64):
#                 cse_var_1: T.int32 = i_outer_outer_outer_j_outer_outer_outer_fused // 4 * 8192 + i_outer_outer_inner * 4096 + i_outer_outer_outer_j_outer_outer_outer_fused % 4 * 256 + j_outer_outer_inner * 4
#                 matmul[cse_var_1:cse_var_1 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 1024:cse_var_1 + 1024 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 2048:cse_var_1 + 2048 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 3072:cse_var_1 + 3072 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 2:cse_var_1 + 2 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 1026:cse_var_1 + 1026 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 2050:cse_var_1 + 2050 + 2] = T.broadcast(T.float32(0), 2)
#                 matmul[cse_var_1 + 3074:cse_var_1 + 3074 + 2] = T.broadcast(T.float32(0), 2)
#                 for k_outer in T.serial(512):
#                     cse_var_20: T.int32 = cse_var_1 + 3074
#                     cse_var_19: T.int32 = cse_var_1 + 3072
#                     cse_var_18: T.int32 = cse_var_1 + 2050
#                     cse_var_17: T.int32 = cse_var_1 + 2048
#                     cse_var_16: T.int32 = cse_var_1 + 2
#                     cse_var_15: T.int32 = cse_var_1 + 1026
#                     cse_var_14: T.int32 = cse_var_1 + 1024
#                     cse_var_13: T.int32 = i_outer_outer_outer_j_outer_outer_outer_fused % 4 * 262144 + j_outer_outer_inner * 4096 + k_outer * 8
#                     cse_var_12: T.int32 = i_outer_outer_outer_j_outer_outer_outer_fused // 4 * 8192 + i_outer_outer_inner * 4096 + k_outer * 2
#                     cse_var_11: T.int32 = cse_var_13 + 6
#                     cse_var_10: T.int32 = cse_var_13 + 4
#                     cse_var_9: T.int32 = cse_var_13 + 2
#                     cse_var_8: T.int32 = cse_var_12 + 3073
#                     cse_var_7: T.int32 = cse_var_12 + 3072
#                     cse_var_6: T.int32 = cse_var_12 + 2049
#                     cse_var_5: T.int32 = cse_var_12 + 2048
#                     cse_var_4: T.int32 = cse_var_12 + 1025
#                     cse_var_3: T.int32 = cse_var_12 + 1024
#                     cse_var_2: T.int32 = cse_var_12 + 1
#                     matmul[cse_var_1:cse_var_1 + 2] = matmul[cse_var_1:cse_var_1 + 2] + T.broadcast(A[cse_var_12], 2) * auto_scheduler_layout_transform[cse_var_13:cse_var_13 + 2]
#                     matmul[cse_var_14:cse_var_14 + 2] = matmul[cse_var_14:cse_var_14 + 2] + T.broadcast(A[cse_var_3], 2) * auto_scheduler_layout_transform[cse_var_13:cse_var_13 + 2]
#                     matmul[cse_var_17:cse_var_17 + 2] = matmul[cse_var_17:cse_var_17 + 2] + T.broadcast(A[cse_var_5], 2) * auto_scheduler_layout_transform[cse_var_13:cse_var_13 + 2]
#                     matmul[cse_var_19:cse_var_19 + 2] = matmul[cse_var_19:cse_var_19 + 2] + T.broadcast(A[cse_var_7], 2) * auto_scheduler_layout_transform[cse_var_13:cse_var_13 + 2]
#                     matmul[cse_var_1:cse_var_1 + 2] = matmul[cse_var_1:cse_var_1 + 2] + T.broadcast(A[cse_var_2], 2) * auto_scheduler_layout_transform[cse_var_9:cse_var_9 + 2]
#                     matmul[cse_var_14:cse_var_14 + 2] = matmul[cse_var_14:cse_var_14 + 2] + T.broadcast(A[cse_var_4], 2) * auto_scheduler_layout_transform[cse_var_9:cse_var_9 + 2]
#                     matmul[cse_var_17:cse_var_17 + 2] = matmul[cse_var_17:cse_var_17 + 2] + T.broadcast(A[cse_var_6], 2) * auto_scheduler_layout_transform[cse_var_9:cse_var_9 + 2]
#                     matmul[cse_var_19:cse_var_19 + 2] = matmul[cse_var_19:cse_var_19 + 2] + T.broadcast(A[cse_var_8], 2) * auto_scheduler_layout_transform[cse_var_9:cse_var_9 + 2]
#                     matmul[cse_var_16:cse_var_16 + 2] = matmul[cse_var_16:cse_var_16 + 2] + T.broadcast(A[cse_var_12], 2) * auto_scheduler_layout_transform[cse_var_10:cse_var_10 + 2]
#                     matmul[cse_var_15:cse_var_15 + 2] = matmul[cse_var_15:cse_var_15 + 2] + T.broadcast(A[cse_var_3], 2) * auto_scheduler_layout_transform[cse_var_10:cse_var_10 + 2]
#                     matmul[cse_var_18:cse_var_18 + 2] = matmul[cse_var_18:cse_var_18 + 2] + T.broadcast(A[cse_var_5], 2) * auto_scheduler_layout_transform[cse_var_10:cse_var_10 + 2]
#                     matmul[cse_var_20:cse_var_20 + 2] = matmul[cse_var_20:cse_var_20 + 2] + T.broadcast(A[cse_var_7], 2) * auto_scheduler_layout_transform[cse_var_10:cse_var_10 + 2]
#                     matmul[cse_var_16:cse_var_16 + 2] = matmul[cse_var_16:cse_var_16 + 2] + T.broadcast(A[cse_var_2], 2) * auto_scheduler_layout_transform[cse_var_11:cse_var_11 + 2]
#                     matmul[cse_var_15:cse_var_15 + 2] = matmul[cse_var_15:cse_var_15 + 2] + T.broadcast(A[cse_var_4], 2) * auto_scheduler_layout_transform[cse_var_11:cse_var_11 + 2]
#                     matmul[cse_var_18:cse_var_18 + 2] = matmul[cse_var_18:cse_var_18 + 2] + T.broadcast(A[cse_var_6], 2) * auto_scheduler_layout_transform[cse_var_11:cse_var_11 + 2]
#                     matmul[cse_var_20:cse_var_20 + 2] = matmul[cse_var_20:cse_var_20 + 2] + T.broadcast(A[cse_var_8], 2) * auto_scheduler_layout_transform[cse_var_11:cse_var_11 + 2]
#         for i in T.parallel(1024):
#             for j in T.serial(1024):
#                 cse_var_21: T.int32 = i * 1024 + j
#                 out[cse_var_21] = matmul[cse_var_21] + C[cse_var_21]
