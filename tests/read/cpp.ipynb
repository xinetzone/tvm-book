// %% [markdown]
// # 测试

// %%
#pragma cling add_library_path("/media/pc/data/lxw/ai/tvm/build")
#pragma cling load("libtvm_runtime.so") // 需要先加载 TVM 运行时库
// #pragma cling add_library_path("../cpp/sym_add/outputs/libs")
// #pragma cling load("libtvm_ext.so") // 再加载插件库
// #include <tvm/runtime/packed_func.h>
// #include <tvm/runtime/registry.h>
// #include <tvm/tir/op.h>
using namespace tvm::runtime;
#pragma cling add_include_path("/media/pc/data/lxw/ai/tvm/include")
// Out:
// input_line_8:8:17: error: use of undeclared identifier 'tvm'
// using namespace tvm::runtime;void __cling_Un1Qu33(void* vpClingValue) {
//                 ^
// Interpreter Error:
