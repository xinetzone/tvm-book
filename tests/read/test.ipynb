# %% [markdown]
# # 测试

# %%
import tvm
from tvm.relax.frontend import nn

class RelaxModel(nn.Module):
    def __init__(self):
        super().__init__()
        ShapeStructInfo
        self.fc1 = nn.Linear(784, 256)
        self.relu1 = nn.ReLU()
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        return x
mod_from_relax, params_from_relax = RelaxModel().export_tvm(
    {"forward": {"x": nn.spec.Tensor((1, 784), "float32")}}
)
mod_from_relax.show()
text = mod_from_relax.script(show_meta=True) # str
roundtrip_mod = tvm.script.from_source(text)
tvm.ir.assert_structural_equal(mod_from_relax, roundtrip_mod) # True
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">forward</span>(x: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">784</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), fc1_weight: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">256</span>, <span style="color: #008000">784</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), fc1_bias: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">256</span>,), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>)) <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">256</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>):
#         R<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;num_input&quot;</span>: <span style="color: #008000">1</span>})
#         <span style="color: #008000; font-weight: bold">with</span> R<span style="color: #AA22FF; font-weight: bold">.</span>dataflow():
#             permute_dims: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">784</span>, <span style="color: #008000">256</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>permute_dims(fc1_weight, axes<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">None</span>)
#             matmul: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">256</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>matmul(x, permute_dims, out_dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;void&quot;</span>)
#             add: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">256</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>add(matmul, fc1_bias)
#             relu: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">256</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>nn<span style="color: #AA22FF; font-weight: bold">.</span>relu(add)
#             gv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">256</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> relu
#             R<span style="color: #AA22FF; font-weight: bold">.</span>output(gv)
#         <span style="color: #008000; font-weight: bold">return</span> gv
# </pre></div>

# %%
path = "/media/pc/data/board/arria10/lxw/tasks/tools/npuusertools/models/test/mirnet/mirnet_newest_se_RGB_opt.onnx"

# %%
import onnx
model = onnx.load(path)

# %%
model
# Out:
# ir_version: 6
# producer_name: "pytorch"
# producer_version: "1.12.1"
# graph {
#   node {
#     input: "input.1"
#     input: "conv_in.weight"
#     output: "onnx::Conv_50"
#     name: "Conv_9"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Conv_50"
#     input: "body.0.body.0.dau_top.body.0.weight"
#     output: "input"
#     name: "Conv_10"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 32
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input"
#     input: "body.0.body.0.dau_top.body.1.weight"
#     output: "onnx::PRelu_52"
#     name: "Conv_11"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_52"
#     input: "onnx::PRelu_175"
#     output: "input.4"
#     name: "PRelu_12"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.4"
#     input: "body.0.body.0.dau_top.body.3.weight"
#     output: "input.8"
#     name: "Conv_13"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 32
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.8"
#     input: "body.0.body.0.dau_top.body.4.weight"
#     output: "input.12"
#     name: "Conv_14"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.12"
#     output: "input.16"
#     name: "GlobalAveragePool_15"
#     op_type: "GlobalAveragePool"
#   }
#   node {
#     input: "input.16"
#     input: "body.0.body.0.dau_top.gcnet.se.1.weight"
#     output: "onnx::PRelu_58"
#     name: "Conv_16"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_58"
#     input: "onnx::PRelu_176"
#     output: "input.20"
#     name: "PRelu_17"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.20"
#     input: "body.0.body.0.dau_top.gcnet.se.3.weight"
#     output: "onnx::Sigmoid_61"
#     name: "Conv_18"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Sigmoid_61"
#     output: "input.24"
#     name: "Sigmoid_19"
#     op_type: "Sigmoid"
#   }
#   node {
#     input: "input.24"
#     input: "body.0.body.0.dau_top.gcnet.channel_add_conv.0.weight"
#     output: "onnx::PRelu_63"
#     name: "Conv_20"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_63"
#     input: "onnx::PRelu_177"
#     output: "input.28"
#     name: "PRelu_21"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.28"
#     input: "body.0.body.0.dau_top.gcnet.channel_add_conv.2.weight"
#     output: "onnx::Add_66"
#     name: "Conv_22"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.12"
#     input: "onnx::Add_66"
#     output: "onnx::PRelu_67"
#     name: "Add_23"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::PRelu_67"
#     input: "onnx::PRelu_175"
#     output: "onnx::Add_69"
#     name: "PRelu_24"
#     op_type: "PRelu"
#   }
#   node {
#     input: "onnx::Add_69"
#     input: "onnx::Conv_50"
#     output: "onnx::Resize_70"
#     name: "Add_25"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Resize_70"
#     input: "onnx::Resize_74"
#     input: "onnx::Resize_179"
#     output: "onnx::Mul_75"
#     name: "Resize_27"
#     op_type: "Resize"
#     attribute {
#       name: "coordinate_transformation_mode"
#       s: "asymmetric"
#       type: STRING
#     }
#     attribute {
#       name: "cubic_coeff_a"
#       f: -0.75
#       type: FLOAT
#     }
#     attribute {
#       name: "mode"
#       s: "nearest"
#       type: STRING
#     }
#     attribute {
#       name: "nearest_mode"
#       s: "floor"
#       type: STRING
#     }
#   }
#   node {
#     input: "body.0.body.0.down2.0.alpha"
#     input: "onnx::Mul_75"
#     output: "input.32"
#     name: "Mul_28"
#     op_type: "Mul"
#   }
#   node {
#     input: "input.32"
#     input: "body.0.body.0.down2.1.weight"
#     output: "input.36"
#     name: "Conv_29"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.36"
#     input: "body.0.body.0.dau_mid.body.0.weight"
#     output: "input.40"
#     name: "Conv_30"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 48
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.40"
#     input: "body.0.body.0.dau_mid.body.1.weight"
#     output: "onnx::PRelu_79"
#     name: "Conv_31"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_79"
#     input: "onnx::PRelu_180"
#     output: "input.44"
#     name: "PRelu_32"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.44"
#     input: "body.0.body.0.dau_mid.body.3.weight"
#     output: "input.48"
#     name: "Conv_33"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 48
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.48"
#     input: "body.0.body.0.dau_mid.body.4.weight"
#     output: "input.52"
#     name: "Conv_34"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.52"
#     output: "input.56"
#     name: "GlobalAveragePool_35"
#     op_type: "GlobalAveragePool"
#   }
#   node {
#     input: "input.56"
#     input: "body.0.body.0.dau_mid.gcnet.se.1.weight"
#     output: "onnx::PRelu_85"
#     name: "Conv_36"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_85"
#     input: "onnx::PRelu_181"
#     output: "input.60"
#     name: "PRelu_37"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.60"
#     input: "body.0.body.0.dau_mid.gcnet.se.3.weight"
#     output: "onnx::Sigmoid_88"
#     name: "Conv_38"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Sigmoid_88"
#     output: "input.64"
#     name: "Sigmoid_39"
#     op_type: "Sigmoid"
#   }
#   node {
#     input: "input.64"
#     input: "body.0.body.0.dau_mid.gcnet.channel_add_conv.0.weight"
#     output: "onnx::PRelu_90"
#     name: "Conv_40"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_90"
#     input: "onnx::PRelu_182"
#     output: "input.68"
#     name: "PRelu_41"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.68"
#     input: "body.0.body.0.dau_mid.gcnet.channel_add_conv.2.weight"
#     output: "onnx::Add_93"
#     name: "Conv_42"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.52"
#     input: "onnx::Add_93"
#     output: "onnx::PRelu_94"
#     name: "Add_43"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::PRelu_94"
#     input: "onnx::PRelu_180"
#     output: "onnx::Add_96"
#     name: "PRelu_44"
#     op_type: "PRelu"
#   }
#   node {
#     input: "onnx::Add_96"
#     input: "input.36"
#     output: "onnx::Resize_97"
#     name: "Add_45"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Resize_97"
#     input: "onnx::Resize_74"
#     input: "onnx::Resize_179"
#     output: "onnx::Mul_102"
#     name: "Resize_47"
#     op_type: "Resize"
#     attribute {
#       name: "coordinate_transformation_mode"
#       s: "asymmetric"
#       type: STRING
#     }
#     attribute {
#       name: "cubic_coeff_a"
#       f: -0.75
#       type: FLOAT
#     }
#     attribute {
#       name: "mode"
#       s: "nearest"
#       type: STRING
#     }
#     attribute {
#       name: "nearest_mode"
#       s: "floor"
#       type: STRING
#     }
#   }
#   node {
#     input: "body.0.body.0.down4.0.alpha"
#     input: "onnx::Mul_102"
#     output: "input.72"
#     name: "Mul_48"
#     op_type: "Mul"
#   }
#   node {
#     input: "input.72"
#     input: "body.0.body.0.down4.1.weight"
#     output: "input.76"
#     name: "Conv_49"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.76"
#     input: "body.0.body.0.dau_bot.body.0.weight"
#     output: "input.80"
#     name: "Conv_50"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 72
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.80"
#     input: "body.0.body.0.dau_bot.body.1.weight"
#     output: "onnx::PRelu_106"
#     name: "Conv_51"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_106"
#     input: "onnx::PRelu_185"
#     output: "input.84"
#     name: "PRelu_52"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.84"
#     input: "body.0.body.0.dau_bot.body.3.weight"
#     output: "input.88"
#     name: "Conv_53"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 72
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.88"
#     input: "body.0.body.0.dau_bot.body.4.weight"
#     output: "input.92"
#     name: "Conv_54"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.92"
#     output: "input.96"
#     name: "GlobalAveragePool_55"
#     op_type: "GlobalAveragePool"
#   }
#   node {
#     input: "input.96"
#     input: "body.0.body.0.dau_bot.gcnet.se.1.weight"
#     output: "onnx::PRelu_112"
#     name: "Conv_56"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_112"
#     input: "onnx::PRelu_186"
#     output: "input.100"
#     name: "PRelu_57"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.100"
#     input: "body.0.body.0.dau_bot.gcnet.se.3.weight"
#     output: "onnx::Sigmoid_115"
#     name: "Conv_58"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Sigmoid_115"
#     output: "input.104"
#     name: "Sigmoid_59"
#     op_type: "Sigmoid"
#   }
#   node {
#     input: "input.104"
#     input: "body.0.body.0.dau_bot.gcnet.channel_add_conv.0.weight"
#     output: "onnx::PRelu_117"
#     name: "Conv_60"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_117"
#     input: "onnx::PRelu_187"
#     output: "input.108"
#     name: "PRelu_61"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.108"
#     input: "body.0.body.0.dau_bot.gcnet.channel_add_conv.2.weight"
#     output: "onnx::Add_120"
#     name: "Conv_62"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.92"
#     input: "onnx::Add_120"
#     output: "onnx::PRelu_121"
#     name: "Add_63"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::PRelu_121"
#     input: "onnx::PRelu_185"
#     output: "onnx::Add_123"
#     name: "PRelu_64"
#     op_type: "PRelu"
#   }
#   node {
#     input: "onnx::Add_123"
#     input: "input.76"
#     output: "onnx::Conv_124"
#     name: "Add_65"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Conv_124"
#     input: "body.0.body.0.dau_bot.body.0.weight"
#     output: "input.112"
#     name: "Conv_66"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 72
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.112"
#     input: "body.0.body.0.dau_bot.body.1.weight"
#     output: "onnx::PRelu_126"
#     name: "Conv_67"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_126"
#     input: "onnx::PRelu_185"
#     output: "input.116"
#     name: "PRelu_68"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.116"
#     input: "body.0.body.0.dau_bot.body.3.weight"
#     output: "input.120"
#     name: "Conv_69"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 72
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.120"
#     input: "body.0.body.0.dau_bot.body.4.weight"
#     output: "input.124"
#     name: "Conv_70"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.124"
#     output: "input.128"
#     name: "GlobalAveragePool_71"
#     op_type: "GlobalAveragePool"
#   }
#   node {
#     input: "input.128"
#     input: "body.0.body.0.dau_bot.gcnet.se.1.weight"
#     output: "onnx::PRelu_132"
#     name: "Conv_72"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_132"
#     input: "onnx::PRelu_186"
#     output: "input.132"
#     name: "PRelu_73"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.132"
#     input: "body.0.body.0.dau_bot.gcnet.se.3.weight"
#     output: "onnx::Sigmoid_135"
#     name: "Conv_74"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Sigmoid_135"
#     output: "input.136"
#     name: "Sigmoid_75"
#     op_type: "Sigmoid"
#   }
#   node {
#     input: "input.136"
#     input: "body.0.body.0.dau_bot.gcnet.channel_add_conv.0.weight"
#     output: "onnx::PRelu_137"
#     name: "Conv_76"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::PRelu_137"
#     input: "onnx::PRelu_187"
#     output: "input.140"
#     name: "PRelu_77"
#     op_type: "PRelu"
#   }
#   node {
#     input: "input.140"
#     input: "body.0.body.0.dau_bot.gcnet.channel_add_conv.2.weight"
#     output: "onnx::Add_140"
#     name: "Conv_78"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.124"
#     input: "onnx::Add_140"
#     output: "onnx::PRelu_141"
#     name: "Add_79"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::PRelu_141"
#     input: "onnx::PRelu_185"
#     output: "onnx::Add_143"
#     name: "PRelu_80"
#     op_type: "PRelu"
#   }
#   node {
#     input: "onnx::Add_143"
#     input: "onnx::Conv_124"
#     output: "onnx::Conv_144"
#     name: "Add_81"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Conv_144"
#     input: "body.0.body.0.up2.0.weight"
#     output: "input.144"
#     name: "Conv_82"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.144"
#     input: "onnx::Resize_74"
#     input: "onnx::Resize_193"
#     output: "onnx::Mul_150"
#     name: "Resize_84"
#     op_type: "Resize"
#     attribute {
#       name: "coordinate_transformation_mode"
#       s: "asymmetric"
#       type: STRING
#     }
#     attribute {
#       name: "cubic_coeff_a"
#       f: -0.75
#       type: FLOAT
#     }
#     attribute {
#       name: "mode"
#       s: "nearest"
#       type: STRING
#     }
#     attribute {
#       name: "nearest_mode"
#       s: "floor"
#       type: STRING
#     }
#   }
#   node {
#     input: "body.0.body.0.up2.1.alpha"
#     input: "onnx::Mul_150"
#     output: "onnx::Concat_151"
#     name: "Mul_85"
#     op_type: "Mul"
#   }
#   node {
#     input: "onnx::Resize_97"
#     input: "onnx::Concat_151"
#     output: "input.148"
#     name: "Concat_86"
#     op_type: "Concat"
#     attribute {
#       name: "axis"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "input.148"
#     input: "body.0.body.0.skff_mid.conv1x1.weight"
#     input: "body.0.body.0.skff_mid.conv1x1.bias"
#     output: "input.152"
#     name: "Conv_87"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.152"
#     input: "body.0.body.0.up4.0.weight"
#     output: "input.156"
#     name: "Conv_88"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.156"
#     input: "onnx::Resize_74"
#     input: "onnx::Resize_193"
#     output: "onnx::Mul_159"
#     name: "Resize_90"
#     op_type: "Resize"
#     attribute {
#       name: "coordinate_transformation_mode"
#       s: "asymmetric"
#       type: STRING
#     }
#     attribute {
#       name: "cubic_coeff_a"
#       f: -0.75
#       type: FLOAT
#     }
#     attribute {
#       name: "mode"
#       s: "nearest"
#       type: STRING
#     }
#     attribute {
#       name: "nearest_mode"
#       s: "floor"
#       type: STRING
#     }
#   }
#   node {
#     input: "body.0.body.0.up4.1.alpha"
#     input: "onnx::Mul_159"
#     output: "onnx::Concat_160"
#     name: "Mul_91"
#     op_type: "Mul"
#   }
#   node {
#     input: "onnx::Resize_70"
#     input: "onnx::Concat_160"
#     output: "input.160"
#     name: "Concat_92"
#     op_type: "Concat"
#     attribute {
#       name: "axis"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "input.160"
#     input: "body.0.body.0.skff_top.conv1x1.weight"
#     input: "body.0.body.0.skff_top.conv1x1.bias"
#     output: "input.164"
#     name: "Conv_93"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "input.164"
#     input: "body.0.body.0.conv_out.weight"
#     output: "onnx::Add_163"
#     name: "Conv_94"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Add_163"
#     input: "onnx::Conv_50"
#     output: "onnx::Add_164"
#     name: "Add_95"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Add_164"
#     input: "onnx::Conv_50"
#     output: "onnx::Conv_165"
#     name: "Add_96"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Conv_165"
#     input: "conv_out.weight"
#     output: "onnx::Mul_166"
#     name: "Conv_97"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 3
#       ints: 3
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "onnx::Cast_1"
#     output: "onnx::Mul_167"
#     name: "Cast_98"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "onnx::Mul_166"
#     input: "onnx::Mul_167"
#     output: "onnx::Add_168"
#     name: "Mul_99"
#     op_type: "Mul"
#   }
#   node {
#     input: "onnx::Add_168"
#     input: "input.1"
#     output: "onnx::Clip_169"
#     name: "Add_100"
#     op_type: "Add"
#   }
#   node {
#     input: "onnx::Clip_169"
#     input: "onnx::Clip_195"
#     input: "onnx::Clip_196"
#     output: "174"
#     name: "Clip_101"
#     op_type: "Clip"
#   }
#   name: "torch_jit"
#   initializer {
#     dims: 32
#     dims: 3
#     dims: 3
#     dims: 3
#     data_type: 1
#     name: "conv_in.weight"
#     raw_data: "\340\201\006\276\254\027\365=\344\362\303\275\'\342\356<\0255\252=\0027\037>L\026\334\275\254\301x\276\0054\207\275s\017E\276\tO[\276^zW=\245\232\216=8t\324=\362\033v\274\303\357\010>\222&d>8\231\002>\270\205\n\276\363\244\033\276\333\3529\276\356|\261=\201\2608=p\220a>w|\267\275\341c\023>\32644=\255f\336=H\017\373\275\265I\225=Y\005Q<b\241\204\275\320\252\211=\311\017a=qo@\276\013\247N\275N[O>\"x\263=E\255\016\276\326\316\226>P\234{\274\370\245\207\276\232\334\264=K\310T\275\357\325K\276\355\244\376\274J\010X\276aq\323\274y\223\037>\013\234\271<\246#\214\275=\370\024>Dco=\354g-=\032\244J\275\003\326\2615\3316\036=\270\332\220\275\312\200\000>\007\t\250=\253\346\"\276k\360\237\274<8\203\275\002D\244=\264\355P>\351I\016>g\366\022=c\253\246=\346\235\231\275\001\266\037\276\03690>\202\356\362=\271\3368\276\276\204\327<{\333k\275t\2772\276r;>>\304`3\274\205\327\202=\201=\275\275\3347:\276)\203\033>\232V`\275\2456\356\275\3010\262=r\246\030\276\203\027\306\275\030\316\025>\336\242\007>\026\225\275\275\334\244F=\220\320\331\275\2250\017>/\252\354\275\273\201\t\2761<\212\275\205\374q\275jg\n>\352\013\013\276\022)y<]C\024>\234\362\347<\200o\316<\266fR=9\025d\276\337H >\016;>\275\"\233\245=\0218\350=\030g\321=\311\033\005\276\032j\317\274!\260\017=\356\177\201=\367\"8>G\005L>\325B\363=\026\243\314=\202\021*\276\207.\371\275\311\246\202\275,\326\004>\031\215\030=h{\310<l\363\"\276\227N\214\275m\211|=\346No<\351\377\006\276\311L\024>\363\324N\275+$\024\275\376\216\351\275\025\354\204\2758\244\'\276\316;\313=h\212K>\300\237\024\274\237\'\020\276 &\003>\361\303\214=\203\023\027>\270\336\030\276\346\"h\273z\350~<\234\276S\275d\035\226\271\366\037v=\033\366\202>5\274[\276\224H\367\275~\326s\275\263\032!\276\351\253,95\262!
#     raw_data: "\371\327\030\277\311\205\r\277N\005U\277\374\335\376>\320\203,>u\257\026?d\032F\277d\275\030\277\263\227\207\275fX*?t\324\265>\364\035g>J\265\005\277]\340U\277\203ih\277\004\327\321\276\230J\323\276\233\307\364\276\232\000\320>\356\261\270\276G\250%\277\235\227\341>\342\366J?\372\331\334=\311M7\277\313\366j\276^{r\276\0169-\275\263\030+\277\001C\361\276? \035\277P\267,?R\3134\275\207b8?  \004?\215]\013>e\233L\277\331WT\277\'\224N\277\034\326\307\276\367\222\035\277\343\215\232\276\023V\002?\307\003\034?\023\300\001\276\342\035\260=\037-\312>j\316\025?\032\265\242\276\234A\270>Xg\334\275\256\305\016?R\366:\275\001\207\002\277i\335;?\205\tT\276\306\0108>\275V?>?\213\343>\370\275\027?\337\245\301\276}8%>\317A^\2774\3027>%\354\005?\256\362\253\276\224\375\362\276+\300\334>\177\313\215\276\234\201X?\235\302\026=;\302\004>\356\273\014\277\325\025~\276Hz\354\276\363\354A?\210b\250=q\2732?}1\356>\353!H?\022\203-?\230z\223>\177\275\246\276\203C \277\244\204\t\277\332OQ\277\313I\256\276\024\023$\276\035R\363\276\351\037\t\277\324M\030?\232P\357\272\035\001 \277Ah\304\276\214\251\216\276\020\tB="
#   }
#   initializer {
#     dims: 32
#     dims: 32
#     dims: 1
#     dims: 1
#     data_type: 1
#     name: "body.0.body.0.dau_top.body.4.weight"
# ...
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.88"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.92"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.96"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_112"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.100"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Sigmoid_115"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.104"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_117"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.108"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_120"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_121"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_123"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Conv_124"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.112"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_126"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.116"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.120"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.124"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.128"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_132"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.132"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Sigmoid_135"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.136"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_137"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.140"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_140"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::PRelu_141"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_143"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Conv_144"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 72
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.144"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 48
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Mul_150"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 48
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Concat_151"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 48
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.148"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 96
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.152"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 48
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.156"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 64
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Mul_159"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Concat_160"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.160"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 64
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "input.164"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_163"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_164"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Conv_165"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Mul_166"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Mul_167"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Add_168"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "onnx::Clip_169"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 128
#           }
#           dim {
#             dim_value: 128
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 11
# }
