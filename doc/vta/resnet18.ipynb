# %% [markdown]
# # VTA resnet18

# %%
import tvm
from tvm import relay
from dataclasses import dataclass
from pathlib import Path
from PIL import Image
from tqdm import tqdm
import numpy as np
from tvm_book.data.classification import ImageFolderDataset

def preprocess_image(
        image: np.ndarray,
        size: tuple[int] = (224, 224),
        mean: tuple[float] = (0.485, 0.456, 0.406),
        std: tuple[float] = (0.229, 0.224, 0.225)
    ):
    im = Image.fromarray(image)
    im = im.resize((256, 256), Image.Resampling.BILINEAR)
    ori_H, ori_W = im.size
    H, W = size
    space_W, space_H = (ori_W - W)//2, (ori_H - H)//2
    im = im.crop((space_W, space_H, ori_W-space_W, ori_H-space_H))
    image = np.array(im, dtype="float32")
    im.close()
    image = image/256
    image -= mean
    image /= std
    return image.astype(np.float32)

@dataclass
class ImageNet:
    root: str
    size: tuple[int] = (224, 224)
    mean: tuple[float] = (0.485, 0.456, 0.406)
    std: tuple[float] = (0.229, 0.224, 0.225)

    def __post_init__(self):
        self.root = Path(self.root) # 数据根目录
        self.valset = ImageFolderDataset(f"{self.root}/val")
        self.trainset = ImageFolderDataset(f"{self.root}/train")

    def calibrateset(self, calibrate_num: int = 200):
        """用于 TVM 量化的校准数据集
        """
        for k, (data, label) in tqdm(enumerate(self.trainset)):
            if k >= calibrate_num:
                break
            image = preprocess_image(data, self.size, self.mean, self.std)
            images = np.expand_dims(image, 0)
            images = images.transpose((0, 3, 1, 2))
            yield {"data": images}


def load_model(input_shape):
    from torchvision.models import resnet18, ResNet18_Weights
    import torch
    model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
    data = torch.randn(*input_shape)
    model = torch.jit.trace(model.eval(), data)
    return model.eval()

input_shape = 1, 3, 224, 224
input_name = "data"
traced_model = load_model(input_shape)
mod, params = relay.frontend.from_pytorch(
    traced_model, 
    [(input_name, input_shape)], 
    # use_parser_friendly_name=True
)
dataset = ImageNet("/media/pc/data/lxw/home/data/datasets/ILSVRC/")
with tvm.transform.PassContext(opt_level=3):
    with relay.quantize.qconfig(
        skip_conv_layers=[],
        calibrate_mode="kl_divergence", 
        weight_scale="max",
        round_for_shift=True,
        # rounding="TONEAREST", # "UPWARD" or "TONEAREST"
        calibrate_skip_layers=[],
        skip_dense_layer=False,
    ):
        qmod = relay.quantize.quantize(mod, params, dataset.calibrateset(calibrate_num=200))
# Out:
# 200it [01:27,  2.29it/s]

# %%
import vta
from tvm import rpc, autotvm

# %%
remote = rpc.LocalSession()
env = vta.get_env()
ctx = remote.ext_dev(0)
assert env.target.device_name == "vta"

# %%
with autotvm.tophub.context(env.target):
    with tvm.transform.PassContext(opt_level=3):
        assert env.BLOCK_IN == env.BLOCK_OUT
        relay_prog = vta.top.graph_pack(
            qmod["main"],
            env.BATCH,
            env.BLOCK_OUT,
            env.WGT_WIDTH,
            start_name="nn.max_pool2d",
            stop_name="nn.adaptive_avg_pool2d",
            device_annot=(env.TARGET == "intelfocl"),
        )
    with vta.build_config(
            opt_level=3,
            disabled_pass={"AlterOpLayout",
                           "tir.CommonSubexprElimTIR"}
        ):
            lib = relay.build(relay_prog,
                              target=env.target,
                              params=params)
    # 将 inference library 发送到远程 RPC 服务器
    temp = tempdir()
    lib.export_library(temp.relpath("graphlib.tar"))
    remote.upload(temp.relpath("graphlib.tar"))
    lib = remote.load_module("graphlib.tar")

# %%
print(relay_prog)
# Out:
# fn (%data: Tensor[(1, 3, 224, 224), float32] /* ty=Tensor[(1, 3, 224, 224), float32] span=aten::_convolution_0.data:0:0 */) -> Tensor[(1, 1000), float32] {
#   %0 = multiply(%data, 48.8058f /* ty=float32 */) /* ty=Tensor[(1, 3, 224, 224), float32] */;
#   %1 = round(%0) /* ty=Tensor[(1, 3, 224, 224), float32] */;
#   %2 = clip(%1, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 3, 224, 224), float32] */;
#   %3 = cast(%2, dtype="int8") /* ty=Tensor[(1, 3, 224, 224), int8] */;
#   %4 = nn.conv2d(%3, meta[relay.Constant][0] /* ty=Tensor[(64, 3, 7, 7), int8] */, strides=[2, 2], padding=[3, 3, 3, 3], channels=64, kernel_size=[7, 7], out_dtype="int32") /* ty=Tensor[(1, 64, 112, 112), int32] */;
#   %5 = add(%4, meta[relay.Constant][1] /* ty=Tensor[(64, 1, 1), int32] */) /* ty=Tensor[(1, 64, 112, 112), int32] */;
#   %6 = nn.relu(%5) /* ty=Tensor[(1, 64, 112, 112), int32] */;
#   %7 = cast(%6, dtype="int64") /* ty=Tensor[(1, 64, 112, 112), int64] */;
#   %8 = fixed_point_multiply(%7, multiplier=1562234240, shift=-8) /* ty=Tensor[(1, 64, 112, 112), int64] */;
#   %9 = clip(%8, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 64, 112, 112), int64] */;
#   %10 = cast(%9, dtype="int32") /* ty=Tensor[(1, 64, 112, 112), int32] */;
#   %11 = cast(%10, dtype="int8") /* ty=Tensor[(1, 64, 112, 112), int8] */;
#   %12 = nn.max_pool2d(%11, pool_size=[3, 3], strides=[2, 2], padding=[1, 1, 1, 1]) /* ty=Tensor[(1, 64, 56, 56), int8] */;
#   %13 = reshape(%12, newshape=[1, 1, 4, 16, 56, 56]) /* ty=Tensor[(1, 1, 4, 16, 56, 56), int8] */;
#   %14 = transpose(%13, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %15 = cast(%14, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %16 = fixed_point_multiply(%15, multiplier=1645474560, shift=0) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %17 = clip(%16, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %18 = cast(%17, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %19 = cast(%18, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %20 = reshape(meta[relay.Constant][2] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %21 = annotation.stop_fusion(%19) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %22 = transpose(%20, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %23 = reshape(meta[relay.Constant][3] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %24 = transpose(%23, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %25 = nn.conv2d(%21, %22, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %26 = broadcast_to(%24, shape=[4, 1, 1, 1, 16]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %27 = add(%25, %26) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %28 = nn.relu(%27) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %29 = cast(%28, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %30 = fixed_point_multiply(%29, multiplier=1401064832, shift=-7) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %31 = clip(%30, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %32 = cast(%31, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %33 = cast(%32, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %34 = reshape(meta[relay.Constant][4] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %35 = annotation.stop_fusion(%33) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %36 = transpose(%34, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %37 = reshape(meta[relay.Constant][5] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %38 = transpose(%37, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %39 = nn.conv2d(%35, %36, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %40 = broadcast_to(%38, shape=[4, 1, 1, 1, 16]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %41 = add(%39, %40) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %42 = cast(%41, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %43 = fixed_point_multiply(%42, multiplier=2069492864, shift=-8) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %44 = clip(%43, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %45 = cast(%44, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %46 = cast(%45, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %47 = annotation.stop_fusion(%46) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %48 = cast(%18, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %49 = annotation.stop_fusion(%48) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %50 = cast(%49, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %51 = fixed_point_multiply(%50, multiplier=1169350144, shift=1) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %52 = cast(%47, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %53 = cast(%51, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %54 = add(%52, %53) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %55 = nn.relu(%54) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %56 = cast(%55, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %57 = fixed_point_multiply(%56, multiplier=1745206016, shift=0) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %58 = clip(%57, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %59 = cast(%58, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %60 = cast(%59, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %61 = reshape(meta[relay.Constant][6] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %62 = annotation.stop_fusion(%60) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %63 = transpose(%61, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %64 = reshape(meta[relay.Constant][7] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %65 = transpose(%64, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %66 = nn.conv2d(%62, %63, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %67 = broadcast_to(%65, shape=[4, 1, 1, 1, 16]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %68 = add(%66, %67) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %69 = nn.relu(%68) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %70 = cast(%69, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %71 = fixed_point_multiply(%70, multiplier=1096199296, shift=-7) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %72 = clip(%71, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %73 = cast(%72, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %74 = cast(%73, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %75 = reshape(meta[relay.Constant][8] /* ty=Tensor[(64, 64, 3, 3), int8] */, newshape=[4, 16, 4, 16, 3, 3]) /* ty=Tensor[(4, 16, 4, 16, 3, 3), int8] */;
#   %76 = annotation.stop_fusion(%74) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %77 = transpose(%75, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(4, 4, 3, 3, 16, 16), int8] */;
#   %78 = reshape(meta[relay.Constant][9] /* ty=Tensor[(64, 1, 1), int32] */, newshape=[4, 16, 1, 1, 1]) /* ty=Tensor[(4, 16, 1, 1, 1), int32] */;
#   %79 = transpose(%78, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %80 = nn.conv2d(%76, %77, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %81 = broadcast_to(%79, shape=[4, 1, 1, 1, 16]) /* ty=Tensor[(4, 1, 1, 1, 16), int32] */;
#   %82 = add(%80, %81) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %83 = cast(%82, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %84 = fixed_point_multiply(%83, multiplier=1162186112, shift=-7) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %85 = clip(%84, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %86 = cast(%85, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %87 = cast(%86, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %88 = annotation.stop_fusion(%87) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %89 = cast(%88, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %90 = fixed_point_multiply(%89, multiplier=1139712000, shift=1) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %91 = cast(%59, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %92 = annotation.stop_fusion(%91) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %93 = cast(%90, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %94 = cast(%92, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %95 = add(%93, %94) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %96 = nn.relu(%95) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %97 = cast(%96, dtype="int64") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %98 = fixed_point_multiply(%97, multiplier=1703142784, shift=0) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %99 = clip(%98, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int64] */;
#   %100 = cast(%99, dtype="int32") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int32] */;
#   %101 = cast(%100, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %102 = reshape(meta[relay.Constant][10] /* ty=Tensor[(128, 64, 3, 3), int8] */, newshape=[8, 16, 4, 16, 3, 3]) /* ty=Tensor[(8, 16, 4, 16, 3, 3), int8] */;
#   %103 = annotation.stop_fusion(%101) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %104 = transpose(%102, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 4, 3, 3, 16, 16), int8] */;
#   %105 = reshape(meta[relay.Constant][11] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %106 = transpose(%105, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %107 = nn.conv2d(%103, %104, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %108 = broadcast_to(%106, shape=[8, 1, 1, 1, 16]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %109 = add(%107, %108) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %110 = nn.relu(%109) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %111 = cast(%110, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %112 = fixed_point_multiply(%111, multiplier=2128034304, shift=-8) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %113 = clip(%112, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %114 = cast(%113, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %115 = cast(%114, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %116 = reshape(meta[relay.Constant][12] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %117 = annotation.stop_fusion(%115) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %118 = transpose(%116, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %119 = reshape(meta[relay.Constant][13] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %120 = transpose(%119, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %121 = nn.conv2d(%117, %118, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %122 = broadcast_to(%120, shape=[8, 1, 1, 1, 16]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %123 = add(%121, %122) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %124 = cast(%123, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %125 = fixed_point_multiply(%124, multiplier=1194984960, shift=-7) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %126 = clip(%125, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %127 = cast(%126, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %128 = cast(%127, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %129 = annotation.stop_fusion(%128) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %130 = cast(%129, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %131 = fixed_point_multiply(%130, multiplier=1381921280, shift=1) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %132 = cast(%100, dtype="int8") /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %133 = reshape(meta[relay.Constant][14] /* ty=Tensor[(128, 64, 1, 1), int8] */, newshape=[8, 16, 4, 16, 1, 1]) /* ty=Tensor[(8, 16, 4, 16, 1, 1), int8] */;
#   %134 = annotation.stop_fusion(%132) /* ty=Tensor[(1, 4, 56, 56, 1, 16), int8] */;
#   %135 = transpose(%133, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 4, 1, 1, 16, 16), int8] */;
#   %136 = reshape(meta[relay.Constant][15] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %137 = transpose(%136, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %138 = nn.conv2d(%134, %135, strides=[2, 2], padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %139 = broadcast_to(%137, shape=[8, 1, 1, 1, 16]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %140 = add(%138, %139) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %141 = cast(%140, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %142 = fixed_point_multiply(%141, multiplier=1712421248, shift=-6) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %143 = clip(%142, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %144 = cast(%143, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %145 = cast(%144, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %146 = annotation.stop_fusion(%145) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %147 = cast(%131, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %148 = cast(%146, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %149 = add(%147, %148) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %150 = nn.relu(%149) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %151 = cast(%150, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %152 = fixed_point_multiply(%151, multiplier=1498585600, shift=0) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %153 = clip(%152, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %154 = cast(%153, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %155 = cast(%154, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %156 = reshape(meta[relay.Constant][16] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %157 = annotation.stop_fusion(%155) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %158 = transpose(%156, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %159 = reshape(meta[relay.Constant][17] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %160 = transpose(%159, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %161 = nn.conv2d(%157, %158, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %162 = broadcast_to(%160, shape=[8, 1, 1, 1, 16]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %163 = add(%161, %162) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %164 = nn.relu(%163) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %165 = cast(%164, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %166 = fixed_point_multiply(%165, multiplier=2092504576, shift=-8) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %167 = clip(%166, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %168 = cast(%167, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %169 = cast(%168, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %170 = reshape(meta[relay.Constant][18] /* ty=Tensor[(128, 128, 3, 3), int8] */, newshape=[8, 16, 8, 16, 3, 3]) /* ty=Tensor[(8, 16, 8, 16, 3, 3), int8] */;
#   %171 = annotation.stop_fusion(%169) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %172 = transpose(%170, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(8, 8, 3, 3, 16, 16), int8] */;
#   %173 = reshape(meta[relay.Constant][19] /* ty=Tensor[(128, 1, 1), int32] */, newshape=[8, 16, 1, 1, 1]) /* ty=Tensor[(8, 16, 1, 1, 1), int32] */;
#   %174 = transpose(%173, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %175 = nn.conv2d(%171, %172, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %176 = broadcast_to(%174, shape=[8, 1, 1, 1, 16]) /* ty=Tensor[(8, 1, 1, 1, 16), int32] */;
#   %177 = add(%175, %176) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %178 = cast(%177, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %179 = fixed_point_multiply(%178, multiplier=1214493824, shift=-7) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %180 = clip(%179, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %181 = cast(%180, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %182 = cast(%181, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %183 = annotation.stop_fusion(%182) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %184 = cast(%154, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %185 = annotation.stop_fusion(%184) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %186 = cast(%185, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %187 = fixed_point_multiply(%186, multiplier=1084432000, shift=1) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %188 = cast(%183, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %189 = cast(%187, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %190 = add(%188, %189) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %191 = nn.relu(%190) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %192 = cast(%191, dtype="int64") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %193 = fixed_point_multiply(%192, multiplier=1644752128, shift=0) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %194 = clip(%193, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int64] */;
#   %195 = cast(%194, dtype="int32") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int32] */;
#   %196 = cast(%195, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %197 = reshape(meta[relay.Constant][20] /* ty=Tensor[(256, 128, 3, 3), int8] */, newshape=[16, 16, 8, 16, 3, 3]) /* ty=Tensor[(16, 16, 8, 16, 3, 3), int8] */;
#   %198 = annotation.stop_fusion(%196) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %199 = transpose(%197, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 8, 3, 3, 16, 16), int8] */;
#   %200 = reshape(meta[relay.Constant][21] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %201 = transpose(%200, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %202 = nn.conv2d(%198, %199, strides=[2, 2], padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %203 = broadcast_to(%201, shape=[16, 1, 1, 1, 16]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %204 = add(%202, %203) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %205 = nn.relu(%204) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %206 = cast(%205, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %207 = fixed_point_multiply(%206, multiplier=1643822976, shift=-8) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %208 = clip(%207, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %209 = cast(%208, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %210 = cast(%209, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %211 = reshape(meta[relay.Constant][22] /* ty=Tensor[(256, 256, 3, 3), int8] */, newshape=[16, 16, 16, 16, 3, 3]) /* ty=Tensor[(16, 16, 16, 16, 3, 3), int8] */;
#   %212 = annotation.stop_fusion(%210) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %213 = transpose(%211, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 16, 3, 3, 16, 16), int8] */;
#   %214 = reshape(meta[relay.Constant][23] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %215 = transpose(%214, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %216 = nn.conv2d(%212, %213, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %217 = broadcast_to(%215, shape=[16, 1, 1, 1, 16]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %218 = add(%216, %217) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %219 = cast(%218, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %220 = fixed_point_multiply(%219, multiplier=1725358976, shift=-8) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %221 = clip(%220, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %222 = cast(%221, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %223 = cast(%222, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %224 = annotation.stop_fusion(%223) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %225 = cast(%224, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %226 = fixed_point_multiply(%225, multiplier=1661553152, shift=2) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %227 = cast(%195, dtype="int8") /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %228 = reshape(meta[relay.Constant][24] /* ty=Tensor[(256, 128, 1, 1), int8] */, newshape=[16, 16, 8, 16, 1, 1]) /* ty=Tensor[(16, 16, 8, 16, 1, 1), int8] */;
#   %229 = annotation.stop_fusion(%227) /* ty=Tensor[(1, 8, 28, 28, 1, 16), int8] */;
#   %230 = transpose(%228, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 8, 1, 1, 16, 16), int8] */;
#   %231 = reshape(meta[relay.Constant][25] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %232 = transpose(%231, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %233 = nn.conv2d(%229, %230, strides=[2, 2], padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %234 = broadcast_to(%232, shape=[16, 1, 1, 1, 16]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %235 = add(%233, %234) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %236 = cast(%235, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %237 = fixed_point_multiply(%236, multiplier=1568853248, shift=-6) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %238 = clip(%237, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %239 = cast(%238, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %240 = cast(%239, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %241 = annotation.stop_fusion(%240) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %242 = cast(%226, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %243 = cast(%241, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %244 = add(%242, %243) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %245 = nn.relu(%244) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %246 = cast(%245, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %247 = fixed_point_multiply(%246, multiplier=1173045888, shift=-1) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %248 = clip(%247, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %249 = cast(%248, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %250 = cast(%249, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %251 = reshape(meta[relay.Constant][26] /* ty=Tensor[(256, 256, 3, 3), int8] */, newshape=[16, 16, 16, 16, 3, 3]) /* ty=Tensor[(16, 16, 16, 16, 3, 3), int8] */;
#   %252 = annotation.stop_fusion(%250) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %253 = transpose(%251, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 16, 3, 3, 16, 16), int8] */;
#   %254 = reshape(meta[relay.Constant][27] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %255 = transpose(%254, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %256 = nn.conv2d(%252, %253, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %257 = broadcast_to(%255, shape=[16, 1, 1, 1, 16]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %258 = add(%256, %257) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %259 = nn.relu(%258) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %260 = cast(%259, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %261 = fixed_point_multiply(%260, multiplier=1784470144, shift=-8) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %262 = clip(%261, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %263 = cast(%262, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %264 = cast(%263, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %265 = reshape(meta[relay.Constant][28] /* ty=Tensor[(256, 256, 3, 3), int8] */, newshape=[16, 16, 16, 16, 3, 3]) /* ty=Tensor[(16, 16, 16, 16, 3, 3), int8] */;
#   %266 = annotation.stop_fusion(%264) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %267 = transpose(%265, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(16, 16, 3, 3, 16, 16), int8] */;
#   %268 = reshape(meta[relay.Constant][29] /* ty=Tensor[(256, 1, 1), int32] */, newshape=[16, 16, 1, 1, 1]) /* ty=Tensor[(16, 16, 1, 1, 1), int32] */;
#   %269 = transpose(%268, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %270 = nn.conv2d(%266, %267, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %271 = broadcast_to(%269, shape=[16, 1, 1, 1, 16]) /* ty=Tensor[(16, 1, 1, 1, 16), int32] */;
#   %272 = add(%270, %271) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %273 = cast(%272, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %274 = fixed_point_multiply(%273, multiplier=1510816256, shift=-7) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %275 = clip(%274, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %276 = cast(%275, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %277 = cast(%276, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %278 = annotation.stop_fusion(%277) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %279 = cast(%249, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %280 = annotation.stop_fusion(%279) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %281 = cast(%280, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %282 = fixed_point_multiply(%281, multiplier=1187750400, shift=1) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %283 = cast(%278, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %284 = cast(%282, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %285 = add(%283, %284) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %286 = nn.relu(%285) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %287 = cast(%286, dtype="int64") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %288 = fixed_point_multiply(%287, multiplier=1889095296, shift=0) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %289 = clip(%288, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int64] */;
#   %290 = cast(%289, dtype="int32") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int32] */;
#   %291 = cast(%290, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %292 = reshape(meta[relay.Constant][30] /* ty=Tensor[(512, 256, 3, 3), int8] */, newshape=[32, 16, 16, 16, 3, 3]) /* ty=Tensor[(32, 16, 16, 16, 3, 3), int8] */;
#   %293 = annotation.stop_fusion(%291) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %294 = transpose(%292, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 16, 3, 3, 16, 16), int8] */;
#   %295 = reshape(meta[relay.Constant][31] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %296 = transpose(%295, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %297 = nn.conv2d(%293, %294, strides=[2, 2], padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %298 = broadcast_to(%296, shape=[32, 1, 1, 1, 16]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %299 = add(%297, %298) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %300 = nn.relu(%299) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %301 = cast(%300, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %302 = fixed_point_multiply(%301, multiplier=1427203200, shift=-7) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %303 = clip(%302, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %304 = cast(%303, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %305 = cast(%304, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %306 = reshape(meta[relay.Constant][32] /* ty=Tensor[(512, 512, 3, 3), int8] */, newshape=[32, 16, 32, 16, 3, 3]) /* ty=Tensor[(32, 16, 32, 16, 3, 3), int8] */;
#   %307 = annotation.stop_fusion(%305) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %308 = transpose(%306, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 32, 3, 3, 16, 16), int8] */;
#   %309 = reshape(meta[relay.Constant][33] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %310 = transpose(%309, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %311 = nn.conv2d(%307, %308, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %312 = broadcast_to(%310, shape=[32, 1, 1, 1, 16]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %313 = add(%311, %312) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %314 = cast(%313, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %315 = fixed_point_multiply(%314, multiplier=1413434496, shift=-7) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %316 = clip(%315, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %317 = cast(%316, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %318 = cast(%317, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %319 = annotation.stop_fusion(%318) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %320 = cast(%319, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %321 = fixed_point_multiply(%320, multiplier=1485063040, shift=1) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %322 = cast(%290, dtype="int8") /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %323 = reshape(meta[relay.Constant][34] /* ty=Tensor[(512, 256, 1, 1), int8] */, newshape=[32, 16, 16, 16, 1, 1]) /* ty=Tensor[(32, 16, 16, 16, 1, 1), int8] */;
#   %324 = annotation.stop_fusion(%322) /* ty=Tensor[(1, 16, 14, 14, 1, 16), int8] */;
#   %325 = transpose(%323, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 16, 1, 1, 16, 16), int8] */;
#   %326 = reshape(meta[relay.Constant][35] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %327 = transpose(%326, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %328 = nn.conv2d(%324, %325, strides=[2, 2], padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %329 = broadcast_to(%327, shape=[32, 1, 1, 1, 16]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %330 = add(%328, %329) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %331 = cast(%330, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %332 = fixed_point_multiply(%331, multiplier=1879589760, shift=-6) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %333 = clip(%332, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %334 = cast(%333, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %335 = cast(%334, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %336 = annotation.stop_fusion(%335) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %337 = cast(%321, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %338 = cast(%336, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %339 = add(%337, %338) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %340 = nn.relu(%339) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %341 = cast(%340, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %342 = fixed_point_multiply(%341, multiplier=1416265984, shift=0) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %343 = clip(%342, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %344 = cast(%343, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %345 = cast(%344, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %346 = reshape(meta[relay.Constant][36] /* ty=Tensor[(512, 512, 3, 3), int8] */, newshape=[32, 16, 32, 16, 3, 3]) /* ty=Tensor[(32, 16, 32, 16, 3, 3), int8] */;
#   %347 = annotation.stop_fusion(%345) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %348 = transpose(%346, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 32, 3, 3, 16, 16), int8] */;
#   %349 = reshape(meta[relay.Constant][37] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %350 = transpose(%349, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %351 = nn.conv2d(%347, %348, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %352 = broadcast_to(%350, shape=[32, 1, 1, 1, 16]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %353 = add(%351, %352) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %354 = nn.relu(%353) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %355 = cast(%354, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %356 = fixed_point_multiply(%355, multiplier=1207375616, shift=-7) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %357 = clip(%356, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %358 = cast(%357, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %359 = cast(%358, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %360 = reshape(meta[relay.Constant][38] /* ty=Tensor[(512, 512, 3, 3), int8] */, newshape=[32, 16, 32, 16, 3, 3]) /* ty=Tensor[(32, 16, 32, 16, 3, 3), int8] */;
#   %361 = annotation.stop_fusion(%359) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %362 = transpose(%360, axes=[0, 2, 4, 5, 1, 3]) /* ty=Tensor[(32, 32, 3, 3, 16, 16), int8] */;
#   %363 = reshape(meta[relay.Constant][39] /* ty=Tensor[(512, 1, 1), int32] */, newshape=[32, 16, 1, 1, 1]) /* ty=Tensor[(32, 16, 1, 1, 1), int32] */;
#   %364 = transpose(%363, axes=[0, 2, 3, 4, 1]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %365 = nn.conv2d(%361, %362, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3], data_layout="NCHW1n16c", kernel_layout="OIHW16o16i", out_dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %366 = broadcast_to(%364, shape=[32, 1, 1, 1, 16]) /* ty=Tensor[(32, 1, 1, 1, 16), int32] */;
#   %367 = add(%365, %366) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %368 = cast(%367, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %369 = fixed_point_multiply(%368, multiplier=1511784704, shift=-8) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %370 = clip(%369, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %371 = cast(%370, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %372 = cast(%371, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %373 = annotation.stop_fusion(%372) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %374 = cast(%373, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %375 = fixed_point_multiply(%374, multiplier=1451261312, shift=3) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %376 = cast(%344, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %377 = annotation.stop_fusion(%376) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %378 = cast(%375, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %379 = cast(%377, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %380 = add(%378, %379) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %381 = nn.relu(%380) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %382 = cast(%381, dtype="int64") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %383 = fixed_point_multiply(%382, multiplier=1405534976, shift=-2) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %384 = clip(%383, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int64] */;
#   %385 = cast(%384, dtype="int32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int32] */;
#   %386 = cast(%385, dtype="int8") /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %387 = annotation.stop_fusion(%386) /* ty=Tensor[(1, 32, 7, 7, 1, 16), int8] */;
#   %388 = cast(%387, dtype="float32") /* ty=Tensor[(1, 32, 7, 7, 1, 16), float32] */;
#   %389 = multiply(%388, 0.184256f /* ty=float32 */) /* ty=Tensor[(1, 32, 7, 7, 1, 16), float32] */;
#   %390 = transpose(%389, axes=[0, 4, 1, 5, 2, 3]) /* ty=Tensor[(1, 1, 32, 16, 7, 7), float32] */;
#   %391 = reshape(%390, newshape=[1, 512, 7, 7]) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %392 = nn.adaptive_avg_pool2d(%391, output_size=[1, 1]) /* ty=Tensor[(1, 512, 1, 1), float32] */;
#   %393 = reshape(%392, newshape=[0, -1, 1, 1]) /* ty=Tensor[(1, 512, 1, 1), float32] */;
#   %394 = squeeze(%393, axis=[2, 3]) /* ty=Tensor[(1, 512), float32] */;
#   %395 = multiply(%394, 15.5491f /* ty=float32 */) /* ty=Tensor[(1, 512), float32] */;
#   %396 = round(%395) /* ty=Tensor[(1, 512), float32] */;
#   %397 = clip(%396, a_min=-127f, a_max=127f) /* ty=Tensor[(1, 512), float32] */;
#   %398 = cast(%397, dtype="int8") /* ty=Tensor[(1, 512), int8] */;
#   %399 = nn.dense(%398, meta[relay.Constant][40] /* ty=Tensor[(1000, 512), int8] */, units=None, out_dtype="int32") /* ty=Tensor[(1, 1000), int32] */;
#   %400 = add(%399, meta[relay.Constant][41] /* ty=Tensor[(1000), int32] */) /* ty=Tensor[(1, 1000), int32] */;
#   %401 = cast(%400, dtype="float32") /* ty=Tensor[(1, 1000), float32] */;
#   multiply(%401, 0.000359364f /* ty=float32 */) /* ty=Tensor[(1, 1000), float32] */
# } /* ty=fn (Tensor[(1, 3, 224, 224), float32]) -> Tensor[(1, 1000), float32] */

# %%
# 下载 ImageNet categories
categ_url = "https://github.com/uwsampl/web-data/raw/main/vta/models"
categ_fn = "synset.txt"
download.download(f"{categ_url}/{categ_fn}", categ_fn)
synset = eval(open(categ_fn).read())
# 下载测试图片
image_url = "https://homes.cs.washington.edu/~moreau/media/vta/cat.jpg"
image_fn = "cat.png"
download.download(image_url, image_fn)
# 准备用于推理的测试图像
image = Image.open(image_fn).resize((224, 224))
plt.imshow(image)
plt.show()
image = np.array(image) - np.array([123.0, 117.0, 104.0])
image /= np.array([58.395, 57.12, 57.375])
image = image.transpose((2, 0, 1))
image = image[np.newaxis, :]
image = np.repeat(image, env.BATCH, axis=0)

# 生成图执行器（graph executor） `m`。
m = graph_executor.GraphModule(lib["default"](ctxes))
# 设置网络参数和输入
m.set_input(**params)
m.set_input("data", image)
